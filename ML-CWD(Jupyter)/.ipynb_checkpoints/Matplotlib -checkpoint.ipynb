# %%
# %matplotlib inline
from matplotlib import pyplot as plt
plt.plot([1,2,3],[8,15,25])
plt.title("This is heading")
plt.xlabel("this is x label")
plt.ylabel("this is y label")
plt.show()

# %%
from matplotlib import pyplot as plt
from matplotlib import style 
style.use("ggplot")
plt.plot([1,2],[1,2],label = "first",linewidth=3)
plt.legend()
plt.show()
